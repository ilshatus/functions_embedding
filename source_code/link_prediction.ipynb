# %%
import numpy as np
import re
from collections import defaultdict
import networkx as nx
from tqdm import tqdm
from node2vec import Node2Vec
import pickle
import multiprocessing
from gensim.models import Word2Vec
import pandas
from abc import ABC, abstractmethod
# Out:
# C:\Users\kolpa\Anaconda3\envs\p3.6-tensorflow1.13\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # Load serialzed graph

# %%
with open('py_data/nx_fc_graph.pickle', 'rb') as f:
    G = pickle.load(f)

# %% [markdown]
# # Load nodes

# %%
nodes = pandas.read_csv('py_data/functions.csv').set_index('id')

# %% [markdown]
# # Defime Function embedding

# %%
class WalkGenerator(ABC):
    @abstractmethod
    def generate(self, G: nx.Graph) -> list:
        pass

# %%
class N2VWalkGenerator(WalkGenerator):
    
    def __init__(self, 
                 p = 0.8, 
                 q = 0.5, 
                 num_walks = 30, 
                 walk_length = 10, 
                 workers = 1):
        self.args = {'p' : p, 
                     'q' : q, 
                     'num_walks' : num_walks, 
                     'walk_length' : walk_length, 
                     'workers' : workers}
    
    def generate(self, G: nx.Graph) -> list:
        node2vec = Node2Vec(G, **self.args)
        return node2vec.walks

# %%
class FunctionEmbedding(object):
    
    def __init__(self, 
                 G: nx.Graph,
                 nodes: pandas.DataFrame,
                 walk_generator: WalkGenerator,
                 p_pos: float = 0.1, 
                 p_neg: float = 0.1,
                 embedding_dim = 128,
                 random_state: int = 0):
        
        self.G = G.copy()
        self.p_pos = p_pos
        self.p_neg = p_neg
        self.rnd = np.random.RandomState(seed = random_state)
        self.embedding_dim = embedding_dim
        self.nodes = nodes
        self.walk_generator = walk_generator
        self._generate_pos_neg_edges()
        self._generate_walks()
        
    def _generate_neg_edges(self, n_neg: int):
        
        nodes = np.array(G.nodes())
        neg_edges = set()
        for i in tqdm(range(n_neg), desc = 'Generating negative edges'):
            while True:
                u, v = self.rnd.choice(nodes, 2, replace=False)
                if not self.G.has_edge(u, v) and (u, v) not in neg_edges:
                    neg_edges.add((u, v))
                    break
        return [edge for edge in neg_edges]
    
    def _generate_pos_neg_edges(self):
        n_edges = G.number_of_edges()
        n_nodes = G.number_of_nodes()

        n_pos = int(self.p_pos * n_edges)
        n_neg = int(self.p_neg * n_edges)

        neg_edges = self._generate_neg_edges(n_neg)

        pos_edges = np.array(self.G.edges())
        ids = self.rnd.choice(n_nodes, n_pos, replace=False)
        pos_edges = pos_edges[ids]
        
        G.remove_edges_from(pos_edges)

        self.pos_edges = pos_edges
        self.neg_edges = neg_edges
        
    def _generate_walks(self):
        self.walks = self.walk_generator.generate(self.G)
    
    def fit_word2vec(self,
                     window = 5, 
                     epochs=10, 
                     workers = multiprocessing.cpu_count() - 1):
        
        self.model = Word2Vec(size = self.embedding_dim, window=window, min_count=0, workers = workers, sg = 1)
        import logging  # Setting up the loggings to monitor gensim
        from time import time  # To time our operations
        logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
        self.model.build_vocab(self.walks, progress_per=10000)
        t = time()
        self.model.train(self.walks, total_examples=self.model.corpus_count, epochs=epochs, report_delay=1)
        print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
        
        in_vecs = []
        out_vecs = []
        for node_id, val in self.model.wv.vocab.items():
            id = val.index
            in_vecs.append((int(node_id), self.model.wv.vectors[id]))
            out_vecs.append((int(node_id), self.model.trainables.syn1neg[id]))
        in_vecs = pandas.DataFrame(in_vecs, columns=['id', 'in_vec']).set_index('id')
        out_vecs = pandas.DataFrame(out_vecs, columns=['id', 'out_vec']).set_index('id')
        vecs = in_vecs.merge(out_vecs, left_index=True, right_index=True)
        self.nodes = self.nodes.merge(vecs, left_index=True, right_index=True)
    
    def _get_score(self, src_node_id: int, trg_node_id: int):
        src_vec = self.nodes.loc[src_node_id].in_vec
        trg_vec = self.nodes.loc[src_node_id].out_vec
        score = src_vec @ trg_vec / (np.linalg.norm(src_vec) * np.linalg.norm(trg_vec))
        return score
    
    def get_accuracy(self, T = 0.5):
        success = 0
        for src, trg in self.pos_edges:
            if self._get_score(src, trg) >= T:
                success += 1
        for src, trg in self.neg_edges:
            if self._get_score(src, trg) < T:
                success += 1
        return success / (len(self.pos_edges) + len(self.neg_edges))

# %%
func_emb = FunctionEmbedding(G, nodes, N2VWalkGenerator(), 0.2, 0.2)
# Out:
# Generating negative edges: 100%|██████████████████████████████████████████████| 102594/102594 [07:30<00:00, 227.60it/s]
# Computing transition probabilities: 100%|███████████████████████████████████| 198960/198960 [00:08<00:00, 23781.53it/s]
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████| 30/30 [02:01<00:00,  4.46s/it]

# %%
func_emb.fit_word2vec()
# Out:
# INFO - 12:13:43: collecting all words and their counts
# INFO - 12:13:43: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 12:13:43: PROGRESS: at sentence #10000, processed 14698 words, keeping 11964 word types
# INFO - 12:13:43: PROGRESS: at sentence #20000, processed 29526 words, keeping 23358 word types
# INFO - 12:13:43: PROGRESS: at sentence #30000, processed 44336 words, keeping 34324 word types
# INFO - 12:13:43: PROGRESS: at sentence #40000, processed 58877 words, keeping 45096 word types
# INFO - 12:13:43: PROGRESS: at sentence #50000, processed 73530 words, keeping 55635 word types
# INFO - 12:13:43: PROGRESS: at sentence #60000, processed 88321 words, keeping 66058 word types
# INFO - 12:13:43: PROGRESS: at sentence #70000, processed 103013 words, keeping 76306 word types
# INFO - 12:13:43: PROGRESS: at sentence #80000, processed 117655 words, keeping 86358 word types
# INFO - 12:13:43: PROGRESS: at sentence #90000, processed 132478 words, keeping 96362 word types
# INFO - 12:13:43: PROGRESS: at sentence #100000, processed 147211 words, keeping 106261 word types
# INFO - 12:13:43: PROGRESS: at sentence #110000, processed 161797 words, keeping 115989 word types
# INFO - 12:13:43: PROGRESS: at sentence #120000, processed 176550 words, keeping 125664 word types
# INFO - 12:13:43: PROGRESS: at sentence #130000, processed 191213 words, keeping 135227 word types
# INFO - 12:13:43: PROGRESS: at sentence #140000, processed 205855 words, keeping 144688 word types
# INFO - 12:13:43: PROGRESS: at sentence #150000, processed 220513 words, keeping 154087 word types
# INFO - 12:13:43: PROGRESS: at sentence #160000, processed 235230 words, keeping 163452 word types
# INFO - 12:13:43: PROGRESS: at sentence #170000, processed 249976 words, keeping 172651 word types
# INFO - 12:13:43: PROGRESS: at sentence #180000, processed 264629 words, keeping 181786 word types
# INFO - 12:13:43: PROGRESS: at sentence #190000, processed 279021 words, keeping 190892 word types
# INFO - 12:13:43: PROGRESS: at sentence #200000, processed 293595 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #210000, processed 308273 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #220000, processed 323099 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #230000, processed 337913 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #240000, processed 352717 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #250000, processed 367491 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #260000, processed 382153 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #270000, processed 396953 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #280000, processed 411641 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #290000, processed 426270 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #300000, processed 440803 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #310000, processed 455430 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #320000, processed 470021 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #330000, processed 484713 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #340000, processed 499388 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #350000, processed 514059 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #360000, processed 528696 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #370000, processed 543276 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #380000, processed 557996 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #390000, processed 572739 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #400000, processed 587589 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #410000, processed 602326 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #420000, processed 617062 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #430000, processed 631703 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #440000, processed 646346 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #450000, processed 660900 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #460000, processed 675572 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #470000, processed 690385 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #480000, processed 705143 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #490000, processed 719760 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #500000, processed 734547 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #510000, processed 749100 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #520000, processed 763879 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #530000, processed 778640 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #540000, processed 793416 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #550000, processed 808017 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #560000, processed 822651 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #570000, processed 837309 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #580000, processed 852061 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #590000, processed 866760 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #600000, processed 881523 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #610000, processed 896246 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #620000, processed 910976 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #630000, processed 925787 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #640000, processed 940482 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #650000, processed 955114 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #660000, processed 969949 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #670000, processed 984497 words, keeping 198960 word types
# INFO - 12:13:43: PROGRESS: at sentence #680000, processed 999226 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #690000, processed 1013880 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #700000, processed 1028514 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #710000, processed 1043240 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #720000, processed 1057733 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #730000, processed 1072497 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #740000, processed 1087164 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #750000, processed 1101844 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #760000, processed 1116622 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #770000, processed 1131403 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #780000, processed 1145981 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #790000, processed 1160603 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #800000, processed 1175256 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #810000, processed 1189818 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #820000, processed 1204438 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #830000, processed 1219032 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #840000, processed 1233667 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #850000, processed 1248268 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #860000, processed 1262969 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #870000, processed 1277677 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #880000, processed 1292276 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #890000, processed 1307009 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #900000, processed 1321602 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #910000, processed 1336406 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #920000, processed 1350918 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #930000, processed 1365478 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #940000, processed 1380076 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #950000, processed 1394928 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #960000, processed 1409574 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #970000, processed 1424319 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #980000, processed 1439234 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #990000, processed 1453884 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1000000, processed 1468763 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1010000, processed 1483502 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1020000, processed 1498197 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1030000, processed 1512785 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1040000, processed 1527500 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1050000, processed 1542167 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1060000, processed 1556904 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1070000, processed 1571626 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1080000, processed 1586318 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1090000, processed 1601011 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1100000, processed 1615785 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1110000, processed 1630336 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1120000, processed 1645037 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1130000, processed 1659830 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1140000, processed 1674534 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1150000, processed 1689236 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1160000, processed 1703809 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1170000, processed 1718442 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1180000, processed 1733091 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1190000, processed 1747723 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1200000, processed 1762353 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1210000, processed 1777014 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1220000, processed 1791594 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1230000, processed 1806178 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1240000, processed 1820815 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1250000, processed 1835460 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1260000, processed 1850180 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1270000, processed 1864831 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1280000, processed 1879626 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1290000, processed 1894502 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1300000, processed 1909245 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1310000, processed 1923867 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1320000, processed 1938622 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1330000, processed 1953624 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1340000, processed 1968336 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1350000, processed 1982919 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1360000, processed 1997568 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1370000, processed 2012234 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1380000, processed 2026863 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1390000, processed 2041598 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1400000, processed 2056260 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1410000, processed 2071167 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1420000, processed 2085824 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1430000, processed 2100560 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1440000, processed 2115195 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1450000, processed 2129946 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1460000, processed 2144579 words, keeping 198960 word types
# INFO - 12:13:44: PROGRESS: at sentence #1470000, processed 2159255 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1480000, processed 2173994 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1490000, processed 2188831 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1500000, processed 2203481 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1510000, processed 2218276 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1520000, processed 2232937 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1530000, processed 2247510 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1540000, processed 2262130 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1550000, processed 2276785 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1560000, processed 2291526 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1570000, processed 2306073 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1580000, processed 2320669 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1590000, processed 2335333 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1600000, processed 2350129 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1610000, processed 2364727 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1620000, processed 2379410 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1630000, processed 2394069 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1640000, processed 2408669 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1650000, processed 2423323 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1660000, processed 2437996 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1670000, processed 2452685 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1680000, processed 2467478 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1690000, processed 2482077 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1700000, processed 2496738 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1710000, processed 2511357 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1720000, processed 2526153 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1730000, processed 2540953 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1740000, processed 2555520 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1750000, processed 2570208 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1760000, processed 2584941 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1770000, processed 2599679 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1780000, processed 2614353 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1790000, processed 2629113 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1800000, processed 2643956 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1810000, processed 2658625 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1820000, processed 2673360 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1830000, processed 2687924 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1840000, processed 2702491 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1850000, processed 2717273 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1860000, processed 2732165 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1870000, processed 2747021 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1880000, processed 2761689 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1890000, processed 2776382 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1900000, processed 2790942 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1910000, processed 2805788 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1920000, processed 2820383 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1930000, processed 2835132 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1940000, processed 2849876 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1950000, processed 2864626 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1960000, processed 2879253 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1970000, processed 2893865 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1980000, processed 2908631 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #1990000, processed 2923362 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2000000, processed 2938045 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2010000, processed 2952771 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2020000, processed 2967563 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2030000, processed 2982339 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2040000, processed 2997056 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2050000, processed 3011711 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2060000, processed 3026475 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2070000, processed 3040995 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2080000, processed 3055727 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2090000, processed 3070346 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2100000, processed 3085109 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2110000, processed 3099940 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2120000, processed 3114636 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2130000, processed 3129263 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2140000, processed 3143918 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2150000, processed 3158510 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2160000, processed 3173239 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2170000, processed 3187842 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2180000, processed 3202488 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2190000, processed 3217064 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2200000, processed 3231863 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2210000, processed 3246436 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2220000, processed 3261198 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2230000, processed 3275925 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2240000, processed 3290857 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2250000, processed 3305656 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2260000, processed 3320322 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2270000, processed 3335002 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2280000, processed 3349485 words, keeping 198960 word types
# INFO - 12:13:45: PROGRESS: at sentence #2290000, processed 3364194 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2300000, processed 3378962 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2310000, processed 3393519 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2320000, processed 3408233 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2330000, processed 3422764 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2340000, processed 3437333 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2350000, processed 3452100 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2360000, processed 3466854 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2370000, processed 3481521 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2380000, processed 3496064 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2390000, processed 3510795 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2400000, processed 3525554 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2410000, processed 3540118 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2420000, processed 3554764 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2430000, processed 3569229 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2440000, processed 3583952 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2450000, processed 3598764 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2460000, processed 3613367 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2470000, processed 3628025 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2480000, processed 3642727 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2490000, processed 3657473 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2500000, processed 3672245 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2510000, processed 3686989 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2520000, processed 3701733 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2530000, processed 3716319 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2540000, processed 3731060 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2550000, processed 3745735 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2560000, processed 3760467 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2570000, processed 3775021 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2580000, processed 3789669 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2590000, processed 3804449 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2600000, processed 3819121 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2610000, processed 3833903 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2620000, processed 3848607 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2630000, processed 3863232 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2640000, processed 3877917 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2650000, processed 3892614 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2660000, processed 3907273 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2670000, processed 3922031 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2680000, processed 3936821 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2690000, processed 3951353 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2700000, processed 3965853 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2710000, processed 3980521 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2720000, processed 3995251 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2730000, processed 4009927 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2740000, processed 4024730 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2750000, processed 4039463 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2760000, processed 4054110 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2770000, processed 4068695 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2780000, processed 4083506 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2790000, processed 4098073 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2800000, processed 4112751 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2810000, processed 4127424 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2820000, processed 4142092 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2830000, processed 4156855 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2840000, processed 4171615 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2850000, processed 4186290 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2860000, processed 4200977 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2870000, processed 4215689 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2880000, processed 4230479 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2890000, processed 4245176 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2900000, processed 4259855 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2910000, processed 4274371 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2920000, processed 4288959 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2930000, processed 4303922 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2940000, processed 4318694 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2950000, processed 4333329 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2960000, processed 4348022 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2970000, processed 4362574 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2980000, processed 4377132 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #2990000, processed 4391843 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3000000, processed 4406636 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3010000, processed 4421385 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3020000, processed 4436035 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3030000, processed 4450638 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3040000, processed 4465320 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3050000, processed 4480082 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3060000, processed 4494896 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3070000, processed 4509704 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3080000, processed 4524388 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3090000, processed 4539163 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3100000, processed 4553807 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3110000, processed 4568243 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3120000, processed 4582957 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3130000, processed 4597658 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3140000, processed 4612366 words, keeping 198960 word types
# INFO - 12:13:46: PROGRESS: at sentence #3150000, processed 4627072 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3160000, processed 4641503 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3170000, processed 4656202 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3180000, processed 4670897 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3190000, processed 4685426 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3200000, processed 4700194 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3210000, processed 4714829 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3220000, processed 4729433 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3230000, processed 4744206 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3240000, processed 4758950 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3250000, processed 4773800 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3260000, processed 4788600 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3270000, processed 4803217 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3280000, processed 4817964 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3290000, processed 4832725 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3300000, processed 4847327 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3310000, processed 4861917 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3320000, processed 4876602 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3330000, processed 4891435 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3340000, processed 4906369 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3350000, processed 4920967 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3360000, processed 4935538 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3370000, processed 4950269 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3380000, processed 4964976 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3390000, processed 4979735 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3400000, processed 4994455 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3410000, processed 5009169 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3420000, processed 5023795 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3430000, processed 5038532 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3440000, processed 5053130 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3450000, processed 5067677 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3460000, processed 5082256 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3470000, processed 5096935 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3480000, processed 5111730 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3490000, processed 5126370 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3500000, processed 5141244 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3510000, processed 5155873 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3520000, processed 5170463 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3530000, processed 5185272 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3540000, processed 5199992 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3550000, processed 5214697 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3560000, processed 5229288 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3570000, processed 5243967 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3580000, processed 5258595 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3590000, processed 5273314 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3600000, processed 5287858 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3610000, processed 5302405 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3620000, processed 5316981 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3630000, processed 5331677 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3640000, processed 5346245 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3650000, processed 5361015 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3660000, processed 5375616 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3670000, processed 5390344 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3680000, processed 5404983 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3690000, processed 5419767 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3700000, processed 5434433 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3710000, processed 5449234 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3720000, processed 5464205 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3730000, processed 5478835 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3740000, processed 5493470 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3750000, processed 5508234 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3760000, processed 5523041 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3770000, processed 5537652 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3780000, processed 5552190 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3790000, processed 5566849 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3800000, processed 5581388 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3810000, processed 5596018 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3820000, processed 5610729 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3830000, processed 5625380 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3840000, processed 5640233 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3850000, processed 5654937 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3860000, processed 5669617 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3870000, processed 5684367 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3880000, processed 5698987 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3890000, processed 5713664 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3900000, processed 5728351 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3910000, processed 5743026 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3920000, processed 5757589 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3930000, processed 5772369 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3940000, processed 5787031 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3950000, processed 5801829 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3960000, processed 5816421 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3970000, processed 5831309 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3980000, processed 5846037 words, keeping 198960 word types
# INFO - 12:13:47: PROGRESS: at sentence #3990000, processed 5860771 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4000000, processed 5875344 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4010000, processed 5889903 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4020000, processed 5904661 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4030000, processed 5919304 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4040000, processed 5933828 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4050000, processed 5948539 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4060000, processed 5963103 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4070000, processed 5977837 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4080000, processed 5992663 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4090000, processed 6007362 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4100000, processed 6022129 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4110000, processed 6036890 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4120000, processed 6051471 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4130000, processed 6066318 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4140000, processed 6081182 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4150000, processed 6095900 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4160000, processed 6110674 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4170000, processed 6125161 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4180000, processed 6140007 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4190000, processed 6154774 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4200000, processed 6169516 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4210000, processed 6184348 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4220000, processed 6198854 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4230000, processed 6213500 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4240000, processed 6228029 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4250000, processed 6242696 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4260000, processed 6257443 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4270000, processed 6272079 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4280000, processed 6286647 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4290000, processed 6301342 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4300000, processed 6316155 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4310000, processed 6330707 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4320000, processed 6345506 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4330000, processed 6360236 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4340000, processed 6374868 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4350000, processed 6389520 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4360000, processed 6404230 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4370000, processed 6418828 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4380000, processed 6433668 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4390000, processed 6448438 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4400000, processed 6463154 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4410000, processed 6477850 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4420000, processed 6492652 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4430000, processed 6507288 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4440000, processed 6521872 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4450000, processed 6536573 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4460000, processed 6551114 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4470000, processed 6565808 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4480000, processed 6580607 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4490000, processed 6595364 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4500000, processed 6610213 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4510000, processed 6624710 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4520000, processed 6639362 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4530000, processed 6653921 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4540000, processed 6668582 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4550000, processed 6683210 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4560000, processed 6697816 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4570000, processed 6712543 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4580000, processed 6727318 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4590000, processed 6742021 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4600000, processed 6756753 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4610000, processed 6771375 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4620000, processed 6785971 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4630000, processed 6800522 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4640000, processed 6815262 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4650000, processed 6829958 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4660000, processed 6844646 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4670000, processed 6859179 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4680000, processed 6873961 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4690000, processed 6888575 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4700000, processed 6903366 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4710000, processed 6917984 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4720000, processed 6932643 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4730000, processed 6947359 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4740000, processed 6962091 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4750000, processed 6976850 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4760000, processed 6991497 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4770000, processed 7006247 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4780000, processed 7020826 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4790000, processed 7035544 words, keeping 198960 word types
# INFO - 12:13:48: PROGRESS: at sentence #4800000, processed 7050232 words, keeping 198960 word types
# ...
# INFO - 12:15:05: EPOCH 3 - PROGRESS: at 71.17% examples, 541741 words/s, in_qsize 13, out_qsize 1
# INFO - 12:15:06: EPOCH 3 - PROGRESS: at 77.90% examples, 543468 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:07: EPOCH 3 - PROGRESS: at 84.52% examples, 543796 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:08: EPOCH 3 - PROGRESS: at 91.01% examples, 543969 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:09: EPOCH 3 - PROGRESS: at 97.52% examples, 544005 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:09: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:15:09: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:15:09: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:15:09: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:15:09: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:15:09: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:15:09: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:15:09: EPOCH - 3 : training on 8766938 raw words (8488471 effective words) took 15.5s, 548460 effective words/s
# INFO - 12:15:10: EPOCH 4 - PROGRESS: at 6.73% examples, 561045 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:11: EPOCH 4 - PROGRESS: at 13.00% examples, 541876 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:12: EPOCH 4 - PROGRESS: at 19.51% examples, 544814 words/s, in_qsize 12, out_qsize 1
# INFO - 12:15:14: EPOCH 4 - PROGRESS: at 26.12% examples, 543781 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:15: EPOCH 4 - PROGRESS: at 32.84% examples, 542509 words/s, in_qsize 11, out_qsize 3
# INFO - 12:15:16: EPOCH 4 - PROGRESS: at 39.80% examples, 547324 words/s, in_qsize 12, out_qsize 1
# INFO - 12:15:17: EPOCH 4 - PROGRESS: at 46.31% examples, 546988 words/s, in_qsize 11, out_qsize 3
# INFO - 12:15:18: EPOCH 4 - PROGRESS: at 52.58% examples, 544074 words/s, in_qsize 14, out_qsize 3
# INFO - 12:15:19: EPOCH 4 - PROGRESS: at 59.65% examples, 546580 words/s, in_qsize 13, out_qsize 1
# INFO - 12:15:20: EPOCH 4 - PROGRESS: at 66.38% examples, 548368 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:21: EPOCH 4 - PROGRESS: at 72.77% examples, 544081 words/s, in_qsize 13, out_qsize 4
# INFO - 12:15:22: EPOCH 4 - PROGRESS: at 79.73% examples, 547258 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:23: EPOCH 4 - PROGRESS: at 86.34% examples, 547865 words/s, in_qsize 10, out_qsize 1
# INFO - 12:15:24: EPOCH 4 - PROGRESS: at 92.96% examples, 548425 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:25: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:15:25: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:15:25: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:15:25: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:15:25: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:15:25: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:15:25: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:15:25: EPOCH - 4 : training on 8766938 raw words (8488094 effective words) took 15.3s, 553903 effective words/s
# INFO - 12:15:26: EPOCH 5 - PROGRESS: at 6.16% examples, 492105 words/s, in_qsize 14, out_qsize 6
# INFO - 12:15:27: EPOCH 5 - PROGRESS: at 13.57% examples, 549221 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:28: EPOCH 5 - PROGRESS: at 20.31% examples, 554032 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:29: EPOCH 5 - PROGRESS: at 26.35% examples, 542958 words/s, in_qsize 8, out_qsize 5
# INFO - 12:15:30: EPOCH 5 - PROGRESS: at 33.53% examples, 553030 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:31: EPOCH 5 - PROGRESS: at 39.92% examples, 549139 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:32: EPOCH 5 - PROGRESS: at 46.53% examples, 550115 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:33: EPOCH 5 - PROGRESS: at 53.15% examples, 550702 words/s, in_qsize 13, out_qsize 1
# INFO - 12:15:34: EPOCH 5 - PROGRESS: at 59.53% examples, 548476 words/s, in_qsize 11, out_qsize 2
# INFO - 12:15:35: EPOCH 5 - PROGRESS: at 66.38% examples, 551397 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:36: EPOCH 5 - PROGRESS: at 72.65% examples, 549443 words/s, in_qsize 13, out_qsize 2
# INFO - 12:15:37: EPOCH 5 - PROGRESS: at 79.16% examples, 548038 words/s, in_qsize 13, out_qsize 1
# INFO - 12:15:38: EPOCH 5 - PROGRESS: at 85.66% examples, 547541 words/s, in_qsize 8, out_qsize 5
# INFO - 12:15:39: EPOCH 5 - PROGRESS: at 92.50% examples, 549348 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:40: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:15:40: EPOCH 5 - PROGRESS: at 99.46% examples, 552048 words/s, in_qsize 5, out_qsize 1
# INFO - 12:15:40: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:15:40: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:15:40: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:15:40: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:15:40: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:15:40: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:15:40: EPOCH - 5 : training on 8766938 raw words (8487937 effective words) took 15.3s, 553890 effective words/s
# INFO - 12:15:41: EPOCH 6 - PROGRESS: at 6.73% examples, 564620 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:42: EPOCH 6 - PROGRESS: at 13.46% examples, 552218 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:43: EPOCH 6 - PROGRESS: at 19.73% examples, 544126 words/s, in_qsize 13, out_qsize 2
# INFO - 12:15:44: EPOCH 6 - PROGRESS: at 26.23% examples, 545975 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:45: EPOCH 6 - PROGRESS: at 32.84% examples, 546743 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:46: EPOCH 6 - PROGRESS: at 39.23% examples, 544683 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:47: EPOCH 6 - PROGRESS: at 45.74% examples, 545555 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:48: EPOCH 6 - PROGRESS: at 52.46% examples, 548254 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:49: EPOCH 6 - PROGRESS: at 58.74% examples, 544170 words/s, in_qsize 13, out_qsize 4
# INFO - 12:15:50: EPOCH 6 - PROGRESS: at 65.58% examples, 547355 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:51: EPOCH 6 - PROGRESS: at 72.20% examples, 548539 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:52: EPOCH 6 - PROGRESS: at 78.70% examples, 547704 words/s, in_qsize 12, out_qsize 1
# INFO - 12:15:53: EPOCH 6 - PROGRESS: at 85.32% examples, 548487 words/s, in_qsize 13, out_qsize 0
# INFO - 12:15:54: EPOCH 6 - PROGRESS: at 91.47% examples, 545853 words/s, in_qsize 10, out_qsize 4
# INFO - 12:15:55: EPOCH 6 - PROGRESS: at 98.89% examples, 550888 words/s, in_qsize 9, out_qsize 1
# INFO - 12:15:55: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:15:55: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:15:55: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:15:55: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:15:55: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:15:55: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:15:55: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:15:55: EPOCH - 6 : training on 8766938 raw words (8487837 effective words) took 15.3s, 553775 effective words/s
# INFO - 12:15:56: EPOCH 7 - PROGRESS: at 6.62% examples, 552247 words/s, in_qsize 14, out_qsize 0
# INFO - 12:15:57: EPOCH 7 - PROGRESS: at 12.77% examples, 531074 words/s, in_qsize 12, out_qsize 4
# INFO - 12:15:59: EPOCH 7 - PROGRESS: at 19.73% examples, 541448 words/s, in_qsize 12, out_qsize 3
# INFO - 12:16:00: EPOCH 7 - PROGRESS: at 26.46% examples, 541020 words/s, in_qsize 13, out_qsize 1
# INFO - 12:16:01: EPOCH 7 - PROGRESS: at 33.30% examples, 545809 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:02: EPOCH 7 - PROGRESS: at 39.92% examples, 547590 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:03: EPOCH 7 - PROGRESS: at 46.31% examples, 545173 words/s, in_qsize 14, out_qsize 1
# INFO - 12:16:04: EPOCH 7 - PROGRESS: at 52.92% examples, 544870 words/s, in_qsize 12, out_qsize 2
# INFO - 12:16:05: EPOCH 7 - PROGRESS: at 59.65% examples, 547116 words/s, in_qsize 14, out_qsize 0
# INFO - 12:16:06: EPOCH 7 - PROGRESS: at 65.93% examples, 544694 words/s, in_qsize 13, out_qsize 1
# INFO - 12:16:07: EPOCH 7 - PROGRESS: at 72.54% examples, 545254 words/s, in_qsize 9, out_qsize 4
# INFO - 12:16:08: EPOCH 7 - PROGRESS: at 79.16% examples, 546334 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:09: EPOCH 7 - PROGRESS: at 85.32% examples, 544348 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:10: EPOCH 7 - PROGRESS: at 92.04% examples, 544736 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:11: EPOCH 7 - PROGRESS: at 98.66% examples, 545829 words/s, in_qsize 12, out_qsize 0
# INFO - 12:16:11: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:16:11: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:16:11: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:16:11: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:16:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:16:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:16:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:16:11: EPOCH - 7 : training on 8766938 raw words (8488356 effective words) took 15.4s, 549535 effective words/s
# INFO - 12:16:12: EPOCH 8 - PROGRESS: at 6.50% examples, 549466 words/s, in_qsize 11, out_qsize 5
# INFO - 12:16:13: EPOCH 8 - PROGRESS: at 13.23% examples, 551344 words/s, in_qsize 11, out_qsize 3
# INFO - 12:16:14: EPOCH 8 - PROGRESS: at 19.96% examples, 552912 words/s, in_qsize 11, out_qsize 2
# INFO - 12:16:15: EPOCH 8 - PROGRESS: at 26.58% examples, 554613 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:16: EPOCH 8 - PROGRESS: at 32.96% examples, 549386 words/s, in_qsize 12, out_qsize 1
# INFO - 12:16:17: EPOCH 8 - PROGRESS: at 39.80% examples, 554214 words/s, in_qsize 12, out_qsize 0
# INFO - 12:16:18: EPOCH 8 - PROGRESS: at 46.19% examples, 551090 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:19: EPOCH 8 - PROGRESS: at 52.58% examples, 549142 words/s, in_qsize 10, out_qsize 3
# INFO - 12:16:20: EPOCH 8 - PROGRESS: at 59.08% examples, 547462 words/s, in_qsize 11, out_qsize 2
# INFO - 12:16:21: EPOCH 8 - PROGRESS: at 65.93% examples, 550460 words/s, in_qsize 11, out_qsize 1
# INFO - 12:16:22: EPOCH 8 - PROGRESS: at 72.08% examples, 546455 words/s, in_qsize 11, out_qsize 3
# INFO - 12:16:23: EPOCH 8 - PROGRESS: at 78.81% examples, 546736 words/s, in_qsize 14, out_qsize 0
# INFO - 12:16:24: EPOCH 8 - PROGRESS: at 85.32% examples, 547103 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:25: EPOCH 8 - PROGRESS: at 91.81% examples, 547040 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:26: EPOCH 8 - PROGRESS: at 98.77% examples, 549189 words/s, in_qsize 11, out_qsize 0
# INFO - 12:16:26: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:16:26: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:16:26: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:16:26: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:16:26: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:16:26: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:16:26: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:16:26: EPOCH - 8 : training on 8766938 raw words (8488429 effective words) took 15.4s, 551688 effective words/s
# INFO - 12:16:27: EPOCH 9 - PROGRESS: at 6.84% examples, 570198 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:28: EPOCH 9 - PROGRESS: at 13.11% examples, 549489 words/s, in_qsize 10, out_qsize 4
# INFO - 12:16:29: EPOCH 9 - PROGRESS: at 19.85% examples, 553336 words/s, in_qsize 14, out_qsize 0
# INFO - 12:16:30: EPOCH 9 - PROGRESS: at 26.58% examples, 555926 words/s, in_qsize 12, out_qsize 1
# INFO - 12:16:31: EPOCH 9 - PROGRESS: at 33.19% examples, 553344 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:32: EPOCH 9 - PROGRESS: at 39.69% examples, 552352 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:33: EPOCH 9 - PROGRESS: at 45.85% examples, 547743 words/s, in_qsize 10, out_qsize 3
# INFO - 12:16:34: EPOCH 9 - PROGRESS: at 52.58% examples, 548568 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:35: EPOCH 9 - PROGRESS: at 59.31% examples, 550163 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:36: EPOCH 9 - PROGRESS: at 65.93% examples, 549935 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:37: EPOCH 9 - PROGRESS: at 72.08% examples, 546886 words/s, in_qsize 12, out_qsize 1
# INFO - 12:16:38: EPOCH 9 - PROGRESS: at 78.81% examples, 548763 words/s, in_qsize 14, out_qsize 0
# INFO - 12:16:40: EPOCH 9 - PROGRESS: at 85.20% examples, 547368 words/s, in_qsize 13, out_qsize 2
# INFO - 12:16:41: EPOCH 9 - PROGRESS: at 92.04% examples, 548809 words/s, in_qsize 12, out_qsize 0
# INFO - 12:16:42: EPOCH 9 - PROGRESS: at 99.00% examples, 551564 words/s, in_qsize 9, out_qsize 0
# INFO - 12:16:42: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:16:42: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:16:42: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:16:42: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:16:42: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:16:42: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:16:42: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:16:42: EPOCH - 9 : training on 8766938 raw words (8488517 effective words) took 15.3s, 553583 effective words/s
# INFO - 12:16:43: EPOCH 10 - PROGRESS: at 6.84% examples, 572147 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:44: EPOCH 10 - PROGRESS: at 13.34% examples, 560812 words/s, in_qsize 14, out_qsize 0
# INFO - 12:16:45: EPOCH 10 - PROGRESS: at 19.96% examples, 559388 words/s, in_qsize 12, out_qsize 1
# INFO - 12:16:46: EPOCH 10 - PROGRESS: at 26.69% examples, 558418 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:47: EPOCH 10 - PROGRESS: at 33.07% examples, 552703 words/s, in_qsize 13, out_qsize 1
# INFO - 12:16:48: EPOCH 10 - PROGRESS: at 39.69% examples, 553147 words/s, in_qsize 12, out_qsize 2
# INFO - 12:16:49: EPOCH 10 - PROGRESS: at 46.42% examples, 555027 words/s, in_qsize 13, out_qsize 1
# INFO - 12:16:50: EPOCH 10 - PROGRESS: at 53.04% examples, 555291 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:51: EPOCH 10 - PROGRESS: at 59.65% examples, 549794 words/s, in_qsize 10, out_qsize 5
# INFO - 12:16:52: EPOCH 10 - PROGRESS: at 66.95% examples, 556237 words/s, in_qsize 14, out_qsize 0
# INFO - 12:16:53: EPOCH 10 - PROGRESS: at 73.45% examples, 553749 words/s, in_qsize 12, out_qsize 1
# INFO - 12:16:54: EPOCH 10 - PROGRESS: at 79.96% examples, 553098 words/s, in_qsize 13, out_qsize 1
# INFO - 12:16:55: EPOCH 10 - PROGRESS: at 86.80% examples, 552303 words/s, in_qsize 12, out_qsize 2
# INFO - 12:16:56: EPOCH 10 - PROGRESS: at 93.76% examples, 554155 words/s, in_qsize 13, out_qsize 0
# INFO - 12:16:57: worker thread finished; awaiting finish of 6 more threads
# INFO - 12:16:57: worker thread finished; awaiting finish of 5 more threads
# INFO - 12:16:57: worker thread finished; awaiting finish of 4 more threads
# INFO - 12:16:57: worker thread finished; awaiting finish of 3 more threads
# INFO - 12:16:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 12:16:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 12:16:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 12:16:57: EPOCH - 10 : training on 8766938 raw words (8487895 effective words) took 15.2s, 559515 effective words/s
# INFO - 12:16:57: training on a 87669380 raw words (84881639 effective words) took 153.7s, 552374 effective words/s
# Time to train the model: 2.56 mins

# %%
func_emb.get_accuracy(0.01)
# Out:
# 0.5334863637249742

# %%
with open('n2v-model.pickle', 'wb') as f:
    pickle.dump(func_emb, f)

# %%
with open('n2v-model.pickle', 'rb') as f:
    func_emb = pickle.load(f)

# %% [markdown]
# # Link prediction 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics, pipeline
from sklearn.preprocessing import StandardScaler

# %%
def prepare_features(model, edges, fnc = lambda a, b: 0.5 * (a + b)):
    X = []
    for src, trg in edges:
        src_vec = model.nodes.loc[src].in_vec
        trg_vec = model.nodes.loc[trg].in_vec
        vec = fnc(src_vec, trg_vec)
        X.append(vec)
    return X

# %%
pos_edges = func_emb.pos_edges
neg_edges = func_emb.neg_edges

# %%
X = prepare_features(func_emb, np.concatenate((pos_edges, neg_edges)))
y = [1] * len(pos_edges) + [0] * len(neg_edges)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
scaler = StandardScaler()
lin_clf = LogisticRegression(C=1)
clf = pipeline.make_pipeline(scaler, lin_clf)

# %%
clf.fit(X_train, y_train)
# Out:
# C:\Users\kolpa\AppData\Roaming\Python\Python36\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('logisticregression',
#                  LogisticRegression(C=1, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='warn', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
print('Accuracy:', metrics.accuracy_score(clf.predict(X_test), y_test))
print('Roc-auc score:', metrics.scorer.roc_auc_scorer(clf, X_test, y_test))
# Out:
# Accuracy: 0.8111993761879234
# Roc-auc score: 0.8845040366085203
